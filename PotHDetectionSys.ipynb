# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 from scipy.sparse import csr_matrix
#       4 from sklearn.neighbors import NearestNeighbors
# ----> 5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       4 from sklearn.neighbors import NearestNeighbors
#       5 import matplotlib.pyplot as plt
# ----> 6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# road_pt = pd.read_csv("accelerometerData-1680702177.csv")

# %%
# df = pd.DataFrame(road_pt)

# %%
# road_pt.isnull().sum()
# Out:
# lat          0
# long         0
# timestamp    0
# xaxis        0
# yaxis        0
# zaxis        0
# dtype: int64

# %%
# road_pt.duplicated().sum()
# Out:
# 4

# %%
# df.drop_duplicates(subset = 'lat',
#                      keep = 'last', inplace=True)
# df
# Out:
#           lat       long      timestamp  xaxis  yaxis     zaxis
# 44  12.971519  79.164603  5042023025548    0.0    0.0  2.368895
# 49  12.970728  79.164553  5042023025409    0.0    0.0  2.111666

# %%
# df.drop_duplicates(subset=['lat','long'])
# Out:
#          lat       long      timestamp  xaxis  yaxis     zaxis
# 0  12.971519  79.164603  5042023025548    0.0    0.0  2.267199
# 1  12.970728  79.164553  5042023025425    0.0    0.0  2.420340

# %%
# z=road_pt['zaxis']
# print(z)
# Out:
# 0     2.267199
# 1     2.420340
# 2     2.988935
# 3     2.096113
# 4     2.988935
# 5     2.864508
# 6     2.407479
# 7     0.000000
# 8     2.685944
# 9     2.353342
# 10    2.685944
# 11    2.576173
# 12    3.526422
# 13    2.293820
# 14    0.000000
# 15    2.537887
# 16    2.003988
# 17    3.263212
# 18    2.117648
# 19    2.111666
# 20    3.454638
# 21    2.938985
# 22    2.893221
# 23    2.130809
# 24    2.098207
# 25    2.115255
# 26    2.685944
# 27    5.343472
# 28    3.313461
# 29    3.560221
# 30    2.267199
# 31    2.735296
# 32    2.242075
# 33    2.021636
# 34    3.004488
# 35    2.202593
# 36    3.560221
# 37    2.079363
# 38    3.446263
# 39    2.519942
# 40    2.391626
# 41    2.063809
# 42    2.557030
# 43    2.289931
# 44    2.368895
# 45    2.167897
# 46    2.893221
# 47    2.644369
# 48    0.000000
# 49    2.111666
# Name: zaxis, dtype: float64

# %%
# dev=[]
# a=3
# def fun():
#     c=0
#     for i in range(len(z)):
#         dev.append(abs(z[i]-a))
#         if((dev[i]>=3)and(dev[i]<=4)):
#             c=c+1
#     print(c)
#     if(c>=0.8*len(z)):
#         print("Good")
#     else:
#         print("bad")
# fun()

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns

# %%
road_pt = pd.read_csv("accelerometerData-1680702177.csv")

# %%
df = pd.DataFrame(road_pt)
df
# Out:
#           lat       long      timestamp     xaxis     yaxis     zaxis
# 0   12.971519  79.164603  5042023025548  0.000000  0.000000  2.267199
# 1   12.970728  79.164553  5042023025425  0.000000  0.000000  2.420340
# 2   12.970728  79.164553  5042023025429  0.000000  0.000000  2.988935
# 3   12.971519  79.164603  5042023025557  0.000000  0.000000  2.096113
# 4   12.970728  79.164553  5042023025429  0.000000  0.000000  2.988935
# 5   12.970728  79.164553  5042023025410  0.000000  0.000000  2.864508
# 6   12.971519  79.164603  5042023025551  0.000000  0.000000  2.407479
# 7   12.970728  79.164553  5042023025419  0.000000  3.528815  0.000000
# 8   12.970728  79.164553  5042023025415  0.000000  0.000000  2.685944
# 9   12.971519  79.164603  5042023025548  0.000000  0.000000  2.353342
# 10  12.970728  79.164553  5042023025416  0.000000  0.000000  2.685944
# 11  12.971519  79.164603  5042023025558  0.000000  0.000000  2.576173
# ...

# %%
df.long.duplicated()
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# Name: long, dtype: bool

# %%
df['lat_round'] = df['lat'].round(6)
df['long_round'] = df['long'].round(6)
df
# Out:
#           lat       long      timestamp     xaxis     yaxis     zaxis  \
# 0   12.971519  79.164603  5042023025548  0.000000  0.000000  2.267199
# 1   12.970728  79.164553  5042023025425  0.000000  0.000000  2.420340
# 2   12.970728  79.164553  5042023025429  0.000000  0.000000  2.988935
# 3   12.971519  79.164603  5042023025557  0.000000  0.000000  2.096113
# 4   12.970728  79.164553  5042023025429  0.000000  0.000000  2.988935
# 5   12.970728  79.164553  5042023025410  0.000000  0.000000  2.864508
# 6   12.971519  79.164603  5042023025551  0.000000  0.000000  2.407479
# 7   12.970728  79.164553  5042023025419  0.000000  3.528815  0.000000
# 8   12.970728  79.164553  5042023025415  0.000000  0.000000  2.685944
# 9   12.971519  79.164603  5042023025548  0.000000  0.000000  2.353342
# 10  12.970728  79.164553  5042023025416  0.000000  0.000000  2.685944
# 11  12.971519  79.164603  5042023025558  0.000000  0.000000  2.576173
# ...

# %%
df.drop_duplicates(subset=['lat_round', 'long_round'], keep = 'first')
# Out:
#          lat       long      timestamp  xaxis  yaxis     zaxis  lat_round  \
# 0  12.971519  79.164603  5042023025548    0.0    0.0  2.267199  12.971519
# 1  12.970728  79.164553  5042023025425    0.0    0.0  2.420340  12.970728
#
#    long_round
# 0   79.164603
# 1   79.164553

# %%
df['lat'] = df['lat'].apply(str)

# %%
df['long'] = df['long'].apply(str)

# %%
df.drop_duplicates(subset=['lat','long'], keep = 'first')
# Out:
#           lat        long      timestamp  xaxis  yaxis     zaxis
# 0  12.9715186   79.164603  5042023025548    0.0    0.0  2.267199
# 1  12.9707282  79.1645534  5042023025425    0.0    0.0  2.420340
